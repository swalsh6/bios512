# %% [markdown]
# # BIOS512 Assignment #5

# %% [markdown]
# 📈 For this assignment we will work with inflation data provided by the [US Bureah of Labor Statistics](https://www.bls.gov/cpi/tables/). The data is provided as `excel` files. We the data for years 2016-2020 in our binder folder under the filename `revised-seasonally-adjusted-indexes-2020.xlsx`.

# %% [markdown]
# Let's read the data in first. You'll need to load both the `tidyverse` and the `readxl` libraries.

# %%
library('tidyverse')
library('readxl')

# %% [markdown]
# Now you should have a function in your session called `read_excel`. Pass in the filename from above as a `string` to the `read_excel` function and capture the `tibble` output with a variable called `df_price_index`.

# %%
read_excel('revised-seasonally-adjusted-indexes-2020.xlsx')
# Out:
#      ITEM   TITLE                        seriesid
# 1    SA0    All items                    CUSR0000SA0
# 2    SA0    All items                    CUSR0000SA0
# 3    SA0    All items                    CUSR0000SA0
# 4    SA0    All items                    CUSR0000SA0
# 5    SA0    All items                    CUSR0000SA0
# 6    SA0    All items                    CUSR0000SA0
# 7    SA0    All items                    CUSR0000SA0
# 8    SA0    All items                    CUSR0000SA0
# 9    SA0    All items                    CUSR0000SA0
# 10   SA0    All items                    CUSR0000SA0
# 11   SA0    All items                    CUSR0000SA0
# 12   SA0    All items                    CUSR0000SA0
# 13   SA0    All items                    CUSR0000SA0
# 14   SA0    All items                    CUSR0000SA0
# 15   SA0    All items                    CUSR0000SA0
# 16   SA0E   Energy                       CUSR0000SA0E
# 17   SA0E   Energy                       CUSR0000SA0E
# 18   SA0E   Energy                       CUSR0000SA0E
# 19   SA0E   Energy                       CUSR0000SA0E
# 20   SA0E   Energy                       CUSR0000SA0E
# 21   SA0E   Energy                       CUSR0000SA0E
# 22   SA0E   Energy                       CUSR0000SA0E
# 23   SA0E   Energy                       CUSR0000SA0E
# 24   SA0E   Energy                       CUSR0000SA0E
# 25   SA0E   Energy                       CUSR0000SA0E
# 26   SA0E   Energy                       CUSR0000SA0E
# 27   SA0E   Energy                       CUSR0000SA0E
# 28   SA0E   Energy                       CUSR0000SA0E
# 29   SA0E   Energy                       CUSR0000SA0E
# 30   SA0E   Energy                       CUSR0000SA0E
# ⋮    ⋮      ⋮                            ⋮
# 6421 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6422 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6423 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6424 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6425 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6426 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6427 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6428 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6429 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6430 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6431 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6432 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6433 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6434 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6435 SS5702 Inpatient hospital services  CWSR0000SS5702
# 6436 SS5703 Outpatient hospital services CWSR0000SS5703
# 6437 SS5703 Outpatient hospital services CWSR0000SS5703
# 6438 SS5703 Outpatient hospital services CWSR0000SS5703
# 6439 SS5703 Outpatient hospital services CWSR0000SS5703
# 6440 SS5703 Outpatient hospital services CWSR0000SS5703
# 6441 SS5703 Outpatient hospital services CWSR0000SS5703
# 6442 SS5703 Outpatient hospital services CWSR0000SS5703
# 6443 SS5703 Outpatient hospital services CWSR0000SS5703
# 6444 SS5703 Outpatient hospital services CWSR0000SS5703
# 6437 714.515 717.000 716.138 717.894 719.650 718.910 721.535
# 6438 742.499 744.595 740.724 738.450 738.732 745.233 748.192
# 6439 741.626 746.928 754.824 753.597 760.272 761.294 763.458
# 6440 772.878 774.905 775.929 780.158 776.398 779.211 781.611
# 6441  99.889  99.756  99.799  99.780  99.927  99.752  99.454
# 6442  99.855  99.749  99.799  99.782  99.929  99.762  99.476
# 6443  99.835  99.770  99.797  99.752  99.940  99.774  99.484
# 6444  99.813  99.769  99.820  99.746  99.942  99.774  99.490
# 6445  99.793  99.765  99.843  99.745  99.939  99.772  99.497
# 6446 671.529 673.960 684.003 686.383 687.228 686.200 686.174
# 6447 713.477 715.197 714.699 716.331 719.142 717.199 717.751
# 6448 741.271 742.880 739.217 736.621 738.292 743.548 744.334
# 6449 740.238 745.201 753.464 751.684 759.834 759.573 759.564
# 6450 771.281 773.086 774.711 778.167 775.921 777.438 777.680

# %% [markdown]
# We want to plot the average `SEASONALLY_ADJUSTED_INDEX` for `Energy`, `Food`, `Shelter`, and `Used cars and trucks` per month for the year 2020.

# %% [markdown]
# You'll need this months vector for several operations:

# %%
months = c('JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC')

# %%
price = read_excel('revised-seasonally-adjusted-indexes-2020.xlsx')

# %% [markdown]
# Here are the operations you'll need to perform:
# - filter for...
#   - `Year == 2020`,
#   - `TITLE %in% c('Energy', 'Food', 'Shelter', 'Used cars and trucks')`
#   - and, `DATA_TYPE == 'SEASONALLY ADJUSTED INDEX'`
# - Pivot the columns for the Months so the table is in long-form and each row represents a month (hint: use `cols = months` with `pivot_longer`)
# - Group by month and `TITLE` then summarize by finding the mean index for each group.
# - And last, use `forcats` to set the levels for the month column (hint: `tct_relevel(name, months)`)

# %% [markdown]
# The first three rows of your table will look something like this:
#
# ![image.png](attachment:4689c0e0-c92a-4b55-a17f-726366972687.png)

# %%
price_pivot = price %>% 
    filter(YEAR==2020,
           TITLE %in% c('Energy', 'Food', 'Shelter', 'Used cars and trucks'),
           DATA_TYPE == 'SEASONALLY ADJUSTED INDEX') %>%
    pivot_longer(cols=months)

# %% [markdown]
# Ok! Now make this plot:
#
# ![image.png](attachment:f46e3063-30b3-4a19-bc9c-111f9804a5ac.png)

# %%
price_reorder = price_pivot %>%
    mutate(name=fct_relevel(name, months)) %>%
    group_by(name, TITLE) %>%
    summarize(value=mean(value))
# Out:
# `summarise()` has grouped output by 'name'. You can override using the `.groups` argument.

# %%
options(repr.plot.width=10, repr.plot.height=5)

p  = ggplot(price_reorder, aes(x = name, y = value, color = TITLE, group=TITLE))

p = p + geom_line() +
    labs(x='Month (2020)',y='Seasonally Adjusted Index')

p
# Out:
# plot without title

# %% [markdown]
# This is how the [USBLS defines the index](https://www.bls.gov/cpi/) (if you're curious):
#
# >  The Consumer Price Index (CPI) is a measure of the average change over time in the prices paid by urban consumers for a market basket of consumer goods and services.
